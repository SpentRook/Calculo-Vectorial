# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline


x,y = np.meshgrid(np.linspace(-2,2,20),np.linspace(-2,2,20)) #Genera los intervalos en x y y

u = x**2*y # Primera componente del campo vectorial
v = x+y  #Segunda componente del campo vectorial

plt.quiver(x,y,u,v, color = 'green')
plt.show()

# %%
from mpl_toolkits.mplot3d import axes3d
# %matplotlib inline


fig = plt.figure()
ax = fig.gca(projection='3d')

x, y, z = np.meshgrid(np.linspace(2, 4, 5), # Rango de valores en el eje x con salto de 0.2
                      np.linspace(2, 4, 5), # Rango de valores en el eje y con salto de 0.2
                      np.linspace(2, 3, 5)) # Rango de valores en el eje z con salto de 0.2

u = y*z  #Primera componente del campo vectorial
v = x*z #Segunda componente del campo vectorial
w = x*y #Tercera componente del campo vectorial

ax.quiver(x, y, z, u, v, w, length=0.04, color = 'green') #Genera el campo vectorial en en espacio

plt.show() #Grafica el campo vectorial
